# %% [markdown]
# # This Python notbook generates interactive 2D velocity fields from 14CARR experiments.
#
# Data are collected from the LEGI opendap server : **http://servdap.legi.grenoble-inp.fr/opendap/coriolis/01EMMA_CYL/**
#
# Plotting, data retrieving and interactive python functions used in this notebook are available in the file *func_14carr.py* in the root directory

# %%
from func_14carr import *
create_plot()
# Out:
# 999 files in folder ESTUARY3a
